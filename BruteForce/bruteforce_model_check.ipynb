# %% [markdown]
# <a href="https://colab.research.google.com/github/myeongseop2/NIDS_project/blob/main/BruteForce/bruteforce_model_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

normal = pd.read_csv("/content/drive/MyDrive/ids/model_save2/normal.csv")

attack = pd.read_csv("/content/drive/MyDrive/ids/model_save2/attack.csv")

# %%
normal['label'] = 0
attack['label'] = 1

# %%
df = pd.concat([normal, attack])

# %%
from sklearn.utils import shuffle

df = shuffle(df)

# %%
data, target = df.drop(columns = ['label']), df['label']

# %%
import numpy as np

data = np.array(data)
target = np.array(target)

data = np.reshape(data, (15027, 1, 21))

# %%
#LSTM 모델들
from keras.models import load_model

model_10000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_10000.h5")
model_20000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_20000.h5")
model_30000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_30000.h5")
model_40000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_40000.h5")
model_50000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_50000.h5")
model_60000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_60000.h5")
model_70000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_70000.h5")
model_80000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_80000.h5")
model_90000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_90000.h5")
model_100000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_100000.h5")
model_110000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_110000.h5")
model_120000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_120000.h5")
model_130000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_130000.h5")
model_140000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_140000.h5")
model_150000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_150000.h5")
model_160000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_160000.h5")
model_170000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_170000.h5")
model_180000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_180000.h5")
model_190000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_190000.h5")
model_200000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_200000.h5")
model_210000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_210000.h5")
model_220000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_220000.h5")
model_230000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_230000.h5")
model_240000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_240000.h5")
model_250000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_250000.h5")
model_260000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_260000.h5")
model_270000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_270000.h5")
model_280000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_280000.h5")
model_290000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_290000.h5")
model_300000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_300000.h5")
model_310000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_310000.h5")
model_320000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_320000.h5")
model_330000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_330000.h5")
model_340000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_340000.h5")
model_350000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_350000.h5")
model_360000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_360000.h5")
model_370000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_370000.h5")
model_380000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_380000.h5")
model_390000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_390000.h5")
model_400000 = load_model("/content/drive/MyDrive/ids/model_save2/LSTM_models/LSTM_400000.h5")

# %%
result_lstm_10000 = model_10000.predict(data)
result_lstm_20000 = model_20000.predict(data)
result_lstm_30000 = model_30000.predict(data)
result_lstm_40000 = model_40000.predict(data)
result_lstm_50000 = model_50000.predict(data)
result_lstm_60000 = model_60000.predict(data)
result_lstm_70000 = model_70000.predict(data)
result_lstm_80000 = model_80000.predict(data)
result_lstm_90000 = model_90000.predict(data)
result_lstm_100000 = model_100000.predict(data)
result_lstm_110000 = model_110000.predict(data)
result_lstm_120000 = model_120000.predict(data)
result_lstm_130000 = model_130000.predict(data)
result_lstm_140000 = model_140000.predict(data)
result_lstm_150000 = model_150000.predict(data)
result_lstm_160000 = model_160000.predict(data)
result_lstm_170000 = model_170000.predict(data)
result_lstm_180000 = model_180000.predict(data)
result_lstm_190000 = model_190000.predict(data)
result_lstm_200000 = model_200000.predict(data)
result_lstm_200000 = model_210000.predict(data)
result_lstm_200000 = model_220000.predict(data)
result_lstm_200000 = model_230000.predict(data)
result_lstm_200000 = model_240000.predict(data)
result_lstm_200000 = model_250000.predict(data)
result_lstm_200000 = model_260000.predict(data)
result_lstm_200000 = model_270000.predict(data)
result_lstm_200000 = model_280000.predict(data)
result_lstm_200000 = model_290000.predict(data)
result_lstm_200000 = model_300000.predict(data)
result_lstm_200000 = model_310000.predict(data)
result_lstm_200000 = model_320000.predict(data)
result_lstm_200000 = model_330000.predict(data)
result_lstm_200000 = model_340000.predict(data)
result_lstm_200000 = model_350000.predict(data)
result_lstm_200000 = model_360000.predict(data)
result_lstm_200000 = model_370000.predict(data)
result_lstm_200000 = model_380000.predict(data)
result_lstm_200000 = model_390000.predict(data)
result_lstm_200000 = model_400000.predict(data)

# %%
#실제 패킷 확인
print('*********************10000*********************')
loss, acc = model_10000.evaluate(data, target, verbose=1)
print('\n*********************20000*********************')
loss, acc = model_20000.evaluate(data, target, verbose=1)
print('\n*********************30000*********************')
loss, acc = model_30000.evaluate(data, target, verbose=1)
print('\n*********************40000*********************')
loss, acc = model_40000.evaluate(data, target, verbose=1)
print('\n*********************50000*********************')
loss, acc = model_50000.evaluate(data, target, verbose=1)
print('\n*********************60000*********************')
loss, acc = model_60000.evaluate(data, target, verbose=1)
print('\n*********************70000*********************')
loss, acc = model_70000.evaluate(data, target, verbose=1)
print('\n*********************80000*********************')
loss, acc = model_80000.evaluate(data, target, verbose=1)
print('\n*********************90000*********************')
loss, acc = model_90000.evaluate(data, target, verbose=1)
print('\n*********************100000*********************')
loss, acc = model_100000.evaluate(data, target, verbose=1)
print('\n*********************110000*********************')
loss, acc = model_110000.evaluate(data, target, verbose=1)
print('\n*********************120000*********************')
loss, acc = model_120000.evaluate(data, target, verbose=1)
print('\n*********************130000*********************')
loss, acc = model_130000.evaluate(data, target, verbose=1)
print('\n*********************140000*********************')
loss, acc = model_140000.evaluate(data, target, verbose=1)
print('\n*********************150000*********************')
loss, acc = model_150000.evaluate(data, target, verbose=1)
print('\n*********************160000*********************')
loss, acc = model_160000.evaluate(data, target, verbose=1)
print('\n*********************170000*********************')
loss, acc = model_170000.evaluate(data, target, verbose=1)
print('\n*********************180000*********************')
loss, acc = model_180000.evaluate(data, target, verbose=1)
print('\n*********************190000*********************')
loss, acc = model_190000.evaluate(data, target, verbose=1)
print('\n*********************200000*********************')
loss, acc = model_200000.evaluate(data, target, verbose=1)
print('\n*********************210000*********************')
loss, acc = model_210000.evaluate(data, target, verbose=1)
print('\n*********************220000*********************')
loss, acc = model_220000.evaluate(data, target, verbose=1)
print('\n*********************230000*********************')
loss, acc = model_230000.evaluate(data, target, verbose=1)
print('\n*********************240000*********************')
loss, acc = model_240000.evaluate(data, target, verbose=1)
print('\n*********************250000*********************')
loss, acc = model_250000.evaluate(data, target, verbose=1)
print('\n*********************260000*********************')
loss, acc = model_260000.evaluate(data, target, verbose=1)
print('\n*********************270000*********************')
loss, acc = model_270000.evaluate(data, target, verbose=1)
print('\n*********************280000*********************')
loss, acc = model_280000.evaluate(data, target, verbose=1)
print('\n*********************290000*********************')
loss, acc = model_290000.evaluate(data, target, verbose=1)
print('\n*********************300000*********************')
loss, acc = model_300000.evaluate(data, target, verbose=1)
print('\n*********************310000*********************')
loss, acc = model_310000.evaluate(data, target, verbose=1)
print('\n*********************320000*********************')
loss, acc = model_320000.evaluate(data, target, verbose=1)
print('\n*********************330000*********************')
loss, acc = model_330000.evaluate(data, target, verbose=1)
print('\n*********************340000*********************')
loss, acc = model_340000.evaluate(data, target, verbose=1)
print('\n*********************350000*********************')
loss, acc = model_350000.evaluate(data, target, verbose=1)
print('\n*********************360000*********************')
loss, acc = model_360000.evaluate(data, target, verbose=1)
print('\n*********************370000*********************')
loss, acc = model_370000.evaluate(data, target, verbose=1)
print('\n*********************380000*********************')
loss, acc = model_380000.evaluate(data, target, verbose=1)
print('\n*********************390000*********************')
loss, acc = model_390000.evaluate(data, target, verbose=1)
print('\n*********************400000*********************')
loss, acc = model_400000.evaluate(data, target, verbose=1)
# Out:
# *********************10000*********************
# 470/470 [==============================] - 2s 3ms/step - loss: 6.6198 - accuracy: 0.4049
#
# *********************20000*********************
# 470/470 [==============================] - 2s 3ms/step - loss: 15.9165 - accuracy: 0.3675
#
# *********************30000*********************
# 470/470 [==============================] - 1s 3ms/step - loss: 7.2806 - accuracy: 0.3004
#
# *********************40000*********************
# 470/470 [==============================] - 1s 3ms/step - loss: 8.9748 - accuracy: 0.4427
#
# *********************50000*********************
# 470/470 [==============================] - 2s 3ms/step - loss: 9.8949 - accuracy: 0.7736
#
# *********************60000*********************
# 470/470 [==============================] - 1s 3ms/step - loss: 2.6767 - accuracy: 0.8097
#
# *********************70000*********************
# 470/470 [==============================] - 1s 3ms/step - loss: 4.7250 - accuracy: 0.8098
# ...

# %%
#실제 패킷 확인
print('*********************10000*********************')
loss, acc = model_10000.evaluate(data, target, verbose=1)
print('\n*********************20000*********************')
loss, acc = model_20000.evaluate(data, target, verbose=1)
print('\n*********************30000*********************')
loss, acc = model_30000.evaluate(data, target, verbose=1)
print('\n*********************40000*********************')
loss, acc = model_40000.evaluate(data, target, verbose=1)
print('\n*********************50000*********************')
loss, acc = model_50000.evaluate(data, target, verbose=1)
print('\n*********************60000*********************')
loss, acc = model_60000.evaluate(data, target, verbose=1)
print('\n*********************70000*********************')
loss, acc = model_70000.evaluate(data, target, verbose=1)
print('\n*********************80000*********************')
loss, acc = model_80000.evaluate(data, target, verbose=1)
print('\n*********************90000*********************')
loss, acc = model_90000.evaluate(data, target, verbose=1)
print('\n*********************100000*********************')
loss, acc = model_100000.evaluate(data, target, verbose=1)
print('\n*********************110000*********************')
loss, acc = model_110000.evaluate(data, target, verbose=1)
print('\n*********************120000*********************')
loss, acc = model_120000.evaluate(data, target, verbose=1)
print('\n*********************130000*********************')
loss, acc = model_130000.evaluate(data, target, verbose=1)
print('\n*********************140000*********************')
loss, acc = model_140000.evaluate(data, target, verbose=1)
print('\n*********************150000*********************')
loss, acc = model_150000.evaluate(data, target, verbose=1)
print('\n*********************160000*********************')
loss, acc = model_160000.evaluate(data, target, verbose=1)
print('\n*********************170000*********************')
loss, acc = model_170000.evaluate(data, target, verbose=1)
print('\n*********************180000*********************')
loss, acc = model_180000.evaluate(data, target, verbose=1)
print('\n*********************190000*********************')
loss, acc = model_190000.evaluate(data, target, verbose=1)
print('\n*********************200000*********************')
loss, acc = model_200000.evaluate(data, target, verbose=1)
print('\n*********************210000*********************')
loss, acc = model_210000.evaluate(data, target, verbose=1)
print('\n*********************220000*********************')
loss, acc = model_220000.evaluate(data, target, verbose=1)
print('\n*********************230000*********************')
loss, acc = model_230000.evaluate(data, target, verbose=1)
print('\n*********************240000*********************')
loss, acc = model_240000.evaluate(data, target, verbose=1)
print('\n*********************250000*********************')
loss, acc = model_250000.evaluate(data, target, verbose=1)
print('\n*********************260000*********************')
loss, acc = model_260000.evaluate(data, target, verbose=1)
print('\n*********************270000*********************')
loss, acc = model_270000.evaluate(data, target, verbose=1)
print('\n*********************280000*********************')
loss, acc = model_280000.evaluate(data, target, verbose=1)
print('\n*********************290000*********************')
loss, acc = model_290000.evaluate(data, target, verbose=1)
print('\n*********************300000*********************')
loss, acc = model_300000.evaluate(data, target, verbose=1)
print('\n*********************310000*********************')
loss, acc = model_310000.evaluate(data, target, verbose=1)
print('\n*********************320000*********************')
loss, acc = model_320000.evaluate(data, target, verbose=1)
print('\n*********************330000*********************')
loss, acc = model_330000.evaluate(data, target, verbose=1)
print('\n*********************340000*********************')
loss, acc = model_340000.evaluate(data, target, verbose=1)
print('\n*********************350000*********************')
loss, acc = model_350000.evaluate(data, target, verbose=1)
print('\n*********************360000*********************')
loss, acc = model_360000.evaluate(data, target, verbose=1)
print('\n*********************370000*********************')
loss, acc = model_370000.evaluate(data, target, verbose=1)
print('\n*********************380000*********************')
loss, acc = model_380000.evaluate(data, target, verbose=1)
print('\n*********************390000*********************')
loss, acc = model_390000.evaluate(data, target, verbose=1)
print('\n*********************400000*********************')
loss, acc = model_400000.evaluate(data, target, verbose=1)
# Out:
# *********************10000*********************
# 9/9 [==============================] - 0s 3ms/step - loss: 15.8207 - accuracy: 0.0116
#
# *********************20000*********************
# 9/9 [==============================] - 0s 3ms/step - loss: 6.5207 - accuracy: 0.5775
#
# *********************30000*********************
# 9/9 [==============================] - 0s 3ms/step - loss: 3.3582 - accuracy: 0.9457
#
# *********************40000*********************
# 9/9 [==============================] - 0s 3ms/step - loss: 27.4973 - accuracy: 0.0116
#
# *********************50000*********************
# 9/9 [==============================] - 0s 3ms/step - loss: 30.2142 - accuracy: 0.0078
#
# *********************60000*********************
# 9/9 [==============================] - 0s 3ms/step - loss: 54.9718 - accuracy: 0.0000e+00
#
# *********************70000*********************
# 9/9 [==============================] - 0s 4ms/step - loss: 52.6835 - accuracy: 0.0000e+00
#
# ...
